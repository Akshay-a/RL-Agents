# %%
import gym
import numpy as np
import random
import math # to use epsilon decay
np.bool = np.bool_
# Potentially: from IPython.display import clear_output # To clear output during training loops
# Potentially: import matplotlib.pyplot as plt # For plotting rewards

# %%
#Another wrapper to alter the reward giving structure , run this cell only when testing for altered env
# RewardShapingWrapper ---
class RewardShapingWrapper(gym.Wrapper):
    def __init__(self, env, new_step_penalty=None, new_goal_reward=None, new_illegal_op_penalty=None):
        """
        A wrapper to modify the reward structure of an environment.

        Args:
            env: The environment instance to wrap.
            new_step_penalty (float, optional): New penalty for each step. Defaults to None (no change).
                                                Should be negative or zero.
            new_goal_reward (float, optional): New reward for reaching the goal. Defaults to None (no change).
            new_illegal_op_penalty (float, optional): New penalty for illegal operations. Defaults to None.
                                                      Should be negative.
        """
        super().__init__(env)
        self.original_rewards = {'step': -1, 'goal': 20, 'illegal': -10} # Default Taxi-v3 rewards

        self.new_step_penalty = new_step_penalty
        self.new_goal_reward = new_goal_reward
        self.new_illegal_op_penalty = new_illegal_op_penalty

        print("RewardShapingWrapper initialized with changes:")
        if new_step_penalty is not None:
            print(f"  Step penalty changed from {self.original_rewards['step']} to {new_step_penalty}")
        if new_goal_reward is not None:
            print(f"  Goal reward changed from {self.original_rewards['goal']} to {new_goal_reward}")
        if new_illegal_op_penalty is not None:
            print(f"  Illegal op penalty changed from {self.original_rewards['illegal']} to {new_illegal_op_penalty}")


    def step(self, action):
        # Get the original observation, reward, done, info from the wrapped environment
        observation, original_reward, done, info = self.env.step(action)

        # Assume 'info' might contain details about why a penalty was given,
        # but for Taxi-v3, we can infer from the reward value itself.
        # This logic is specific to how Taxi-v3 assigns rewards.

        modified_reward = original_reward # Start with the original reward

        # --- Apply modifications based on the original reward's meaning ---
        if original_reward == self.original_rewards['goal']: # Successful drop-off
            if self.new_goal_reward is not None:
                modified_reward = self.new_goal_reward
            # Also apply step penalty if it's defined, as Taxi-v3's +20 is standalone
            if self.new_step_penalty is not None and self.new_goal_reward is not None:
                 # If we define a new goal reward, we assume it INCLUDES the step cost consideration
                 # If only step penalty is changed, the original +20 is kept, and step penalty applies on top
                 pass # Handled if new_goal_reward is set
            elif self.new_step_penalty is not None and self.new_goal_reward is None:
                 modified_reward = self.original_rewards['goal'] + self.new_step_penalty


        elif original_reward == self.original_rewards['illegal']: # Illegal pickup/dropoff
            if self.new_illegal_op_penalty is not None:
                modified_reward = self.new_illegal_op_penalty
            # Also apply step penalty if defined
            if self.new_step_penalty is not None and self.new_illegal_op_penalty is not None:
                pass # Assume new_illegal_op_penalty includes step cost consideration
            elif self.new_step_penalty is not None and self.new_illegal_op_penalty is None:
                modified_reward = self.original_rewards['illegal'] + self.new_step_penalty


        elif original_reward == self.original_rewards['step']: # Just a normal step
            if self.new_step_penalty is not None:
                modified_reward = self.new_step_penalty

        # If the original_reward was something else (e.g. from a different env),
        # we don't modify it unless specific rules are added.
        # For Taxi-v3, the above conditions cover the main reward signals.

        return observation, modified_reward, done, info

# %%
#A wrapper for Taxi-v3 that introduces action noise.With probability `action_noise_prob`, a random action is taken instead of the intended one.
class NoisyTaxiWrapper(gym.Wrapper):
    def __init__(self, env, action_noise_prob=0.1):
        super().__init__(env)
        self.action_noise_prob = action_noise_prob
        if not (0.0 <= self.action_noise_prob <= 1.0):
            raise ValueError("action_noise_prob must be between 0.0 and 1.0")
        print(f"NoisyTaxiWrapper initialized with action_noise_prob = {self.action_noise_prob}")

    def step(self, action):
        """
        Overrides the step method to potentially inject noise.
        """
        if random.random() < self.action_noise_prob:
            # Noise occurs: take a random action
            actual_action = self.env.action_space.sample()
            # print(f"NOISE! Intended: {action}, Actual: {actual_action}") # For debugging
        else:
            # No noise: take the intended action
            actual_action = action

        # Call the step method of the underlying environment with the (potentially modified) action
        return self.env.step(actual_action)

    #wrapper will pass other remaining calls to the original env by default.

#env = gym.make("Taxi-v3")
base_env = gym.make("Taxi-v3")
# Let's try with 20% action noise
noise_probability = 0.2
#env = NoisyTaxiWrapper(base_env, action_noise_prob=noise_probability)
noisy_env = NoisyTaxiWrapper(base_env, action_noise_prob=noise_probability)
env = RewardShapingWrapper(noisy_env, new_step_penalty=-0.5, new_goal_reward=50)
#Observations after adding Noise to the environment:
"""
for adding Noise 20% of the time
even after running the agent with 50K Episodes, it failed badly( -ve avg reward) , its taking long steps when running evaluation episodes.
Primary reaason could be optimal Q values are heavily penalized with bad actions which happen 20% of the time , this makes Q values mix of good actions and bad actions and agent leading to take sub optimal routes
The noise bumps the agent a lot. More steps means more -1 penalties, dragging the total score down.
Harder to Tell What's What: When something bad happens, was it my chosen action or just the noise? The agent needs way more tries to figure that out compared to a clean environment.

It's picking what its Q-table says is best given the noise.
Maybe a slightly longer path is less risky if a random move happens – like, a random move on a short, tricky path is a disaster, but on a longer, open path, it's not so bad. So the Q-values for that "safer but longer" approach might end up higher.

Next steps -> try to reduce penality from 1 to 0.5 and increase reward to 50 ( from 20):
This makes the avg reward net positive because +50 covers most of the incorrect path that was taken by the agent, making the better actions with higher reward
but problem with low penality for each step looks like agent just wanders before reaching goal ( i clearely observed this, have to figure out a way to prove this, todo task for now) , same i am not sure was existing before for default reward values

Next try to revert to default reward structure and decrease the learning rate so that it learns to filter out the noise.
"""
# Out:
# NoisyTaxiWrapper initialized with action_noise_prob = 0.2
# RewardShapingWrapper initialized with changes:
#   Step penalty changed from -1 to -0.5
#   Goal reward changed from 20 to 50
# '\nfor adding Noise 20% of the time\neven after running the agent with 50K Episodes, it failed badly( -ve avg reward) , its taking long steps when running evaluation episodes.\nPrimary reaason could be optimal Q values are heavily penalized with bad actions which happen 20% of the time , this makes Q values mix of good actions and bad actions and agent leading to take sub optimal routes\nThe noise bumps the agent a lot. More steps means more -1 penalties, dragging the total score down.\nHarder to Tell What\'s What: When something bad happens, was it my chosen action or just the noise? The agent needs way more tries to figure that out compared to a clean environment.\n\nIt\'s picking what its Q-table says is best given the noise. \nMaybe a slightly longer path is less risky if a random move happens – like, a random move on a short, tricky path is a disaster, but on a longer, open path, it\'s not so bad. So the Q-values for that "safer but longer" approach might end up higher.\nNext steps -> try to reduce penality from 1 to 0.5 and increase reward to 50 ( from 20):\n'

# %%
#intialize Q table , empty numpy array with states and actions
num_states=env.observation_space.n
num_actions=env.action_space.n
q_table=np.zeros((num_states,num_actions))
print("Actions: 0=South, 1=North, 2=East, 3=West, 4=Pickup, 5=Dropoff")
# Out:
# Actions: 0=South, 1=North, 2=East, 3=West, 4=Pickup, 5=Dropoff

# %%
#hyperparameters
learning_rate = 0.1  # Alpha
discount_factor = 0.99 # Gamma

epsilon = 1.0  # Initial exploration rate
max_epsilon = 1.0
min_epsilon = 0.05
epsilon_decay_rate = 0.0001 #have to

num_episodes = 25000

# %%
rewards_all_episodes = []  # Store rewards for plotting learning curve

for episode in range(num_episodes):
    # Reset environment for new episode
    state = env.reset()  # Get initial state
    done = False
    current_episode_reward = 0

    while not done:
        # STEP 1: EXPLORATION vs EXPLOITATION (Epsilon-greedy strategy)
        # Generate random number between 0 and 1
        exploration_threshold = random.uniform(0, 1)

        if exploration_threshold > epsilon:
            # EXPLOITATION: choose action with highest q-value for current state
            action = np.argmax(q_table[state, :])
        else:
            # EXPLORATION: choose random action
            action = env.action_space.sample()

        # STEP 2: take action and observe results
        #print(env.step(action))
        next_state, reward, done, info = env.step(action)

        # STEP 3: UPDATE Q-TABLE using Bellman equation
        # Q(s,a) = Q(s,a) + α[r + γ * max(Q(s',a')) - Q(s,a)]

        if done:
            # If episode is finished, there's no future reward
            # Q(s,a) = Q(s,a) + α[r + 0 - Q(s,a)]
            q_table[state, action] = q_table[state, action] + learning_rate * (
                reward - q_table[state, action]
            )
        else:
            # Normal Q-value update with future reward consideration
            # Q(s,a) = Q(s,a) + α[r + γ * max(Q(s',a')) - Q(s,a)]
            q_table[state, action] = q_table[state, action] + learning_rate * (
                reward + discount_factor * np.max(q_table[next_state, :]) - q_table[state, action]
            )

        # STEP 4: UPDATE STATE and accumulate reward
        state = next_state
        current_episode_reward += reward

    # STEP 5: DECAY EPSILON after each episode
    # Gradually reduce exploration as agent learns
    epsilon = min_epsilon + (max_epsilon - min_epsilon) * math.exp(-epsilon_decay_rate * episode)

    # Store episode reward for analysis
    rewards_all_episodes.append(current_episode_reward)

    # Print progress every 1000 episodes
    if (episode + 1) % 1000 == 0:
        #clear_output(wait=True)
        avg_reward = np.mean(rewards_all_episodes[-1000:])  # Average of last 1000 episodes
        print(f"Episode: {episode + 1}/{num_episodes}")
        print(f"Epsilon: {epsilon:.3f}")
        print(f"Average reward (last 1000 episodes): {avg_reward:.2f}")
        print(f"Current episode reward: {current_episode_reward}")
        print("-" * 50)

print("Training finished!")
# Out:
# Episode: 1000/25000
# Epsilon: 0.910
# Average reward (last 1000 episodes): -698.07
# Current episode reward: -720.0
# --------------------------------------------------
# Episode: 2000/25000
# Epsilon: 0.828
# Average reward (last 1000 episodes): -514.79
# Current episode reward: -467.0
# --------------------------------------------------
# Episode: 3000/25000
# Epsilon: 0.754
# Average reward (last 1000 episodes): -298.15
# Current episode reward: -137.0
# --------------------------------------------------
# Episode: 4000/25000
# Epsilon: 0.687
# Average reward (last 1000 episodes): -179.00
# Current episode reward: -199.5
# --------------------------------------------------
# Episode: 5000/25000
# Epsilon: 0.626
# Average reward (last 1000 episodes): -119.82
# Current episode reward: -245.5
# --------------------------------------------------
# Episode: 6000/25000
# Epsilon: 0.571
# Average reward (last 1000 episodes): -80.90
# Current episode reward: -22.5
# --------------------------------------------------
# Episode: 7000/25000
# Epsilon: 0.522
# Average reward (last 1000 episodes): -55.60
# Current episode reward: 21.0
# --------------------------------------------------
# Episode: 8000/25000
# Epsilon: 0.477
# Average reward (last 1000 episodes): -44.41
# Current episode reward: 2.5
# --------------------------------------------------
# Episode: 9000/25000
# Epsilon: 0.436
# Average reward (last 1000 episodes): -29.68
# Current episode reward: -34.0
# --------------------------------------------------
# Episode: 10000/25000
# Epsilon: 0.400
# Average reward (last 1000 episodes): -21.28
# Current episode reward: -25.0
# --------------------------------------------------
# Episode: 11000/25000
# Epsilon: 0.366
# Average reward (last 1000 episodes): -12.27
# Current episode reward: -30.5
# --------------------------------------------------
# Episode: 12000/25000
# Epsilon: 0.336
# Average reward (last 1000 episodes): -8.19
# Current episode reward: -49.0
# --------------------------------------------------
# Episode: 13000/25000
# Epsilon: 0.309
# Average reward (last 1000 episodes): -6.29
# Current episode reward: -8.5
# --------------------------------------------------
# Episode: 14000/25000
# Epsilon: 0.284
# Average reward (last 1000 episodes): 1.75
# Current episode reward: 40.5
# --------------------------------------------------
# Episode: 15000/25000
# Epsilon: 0.262
# Average reward (last 1000 episodes): 3.61
# Current episode reward: -16.5
# --------------------------------------------------
# Episode: 16000/25000
# Epsilon: 0.242
# Average reward (last 1000 episodes): 3.68
# Current episode reward: 33.5
# --------------------------------------------------
# Episode: 17000/25000
# Epsilon: 0.224
# Average reward (last 1000 episodes): 8.57
# Current episode reward: -5.5
# --------------------------------------------------
# Episode: 18000/25000
# Epsilon: 0.207
# Average reward (last 1000 episodes): 13.07
# Current episode reward: 21.5
# --------------------------------------------------
# Episode: 19000/25000
# Epsilon: 0.192
# Average reward (last 1000 episodes): 13.77
# Current episode reward: 30.0
# --------------------------------------------------
# Episode: 20000/25000
# Epsilon: 0.179
# Average reward (last 1000 episodes): 13.48
# Current episode reward: 4.5
# --------------------------------------------------
# Episode: 21000/25000
# Epsilon: 0.166
# Average reward (last 1000 episodes): 17.99
# Current episode reward: 32.5
# --------------------------------------------------
# Episode: 22000/25000
# Epsilon: 0.155
# Average reward (last 1000 episodes): 17.79
# Current episode reward: 21.0
# --------------------------------------------------
# Episode: 23000/25000
# Epsilon: 0.145
# Average reward (last 1000 episodes): 18.47
# Current episode reward: 9.5
# --------------------------------------------------
# Episode: 24000/25000
# Epsilon: 0.136
# Average reward (last 1000 episodes): 20.03
# Current episode reward: 40.0
# --------------------------------------------------
# Episode: 25000/25000
# Epsilon: 0.128
# Average reward (last 1000 episodes): 20.66
# Current episode reward: 23.5
# --------------------------------------------------
# Training finished!

# %%
import matplotlib.pyplot as plt

# Calculate a moving average of rewards to smooth out the curve
# This makes it easier to see trends.
window_size = 100 # Plot average reward over this many episodes
if len(rewards_all_episodes) >= window_size:
    moving_avg_rewards = np.convolve(rewards_all_episodes, np.ones(window_size)/window_size, mode='valid')
else:
    # Handle cases where there are fewer episodes than the window size
    # For simplicity, we can just plot the raw rewards or a smaller window
    moving_avg_rewards = rewards_all_episodes
    print(f"Warning: Fewer episodes ({len(rewards_all_episodes)}) than moving average window ({window_size}). Plotting raw or partially averaged rewards.")


# 1. Plot of Rewards per Episode (with Moving Average)
plt.figure(figsize=(12, 6))
plt.plot(rewards_all_episodes, label='Reward per Episode', alpha=0.5) # Raw rewards
if len(moving_avg_rewards) > 0: # Ensure moving_avg_rewards is not empty
    # Adjust x-axis for moving average to align it properly
    # The moving average starts after 'window_size - 1' episodes
    plt.plot(np.arange(window_size -1, len(rewards_all_episodes)), moving_avg_rewards, label=f'Moving Average ({window_size} episodes)', color='red', linewidth=2)
plt.xlabel('Episode')
plt.ylabel('Total Reward')
plt.title('Rewards per Episode during Training')
plt.legend()
plt.grid(True)
plt.show()

# 2. Plot of Epsilon Decay (Optional, but good for sanity check)
plt.figure(figsize=(12, 6))
epsilon_values_over_episodes = [min_epsilon + (max_epsilon - min_epsilon) * math.exp(-epsilon_decay_rate * ep) for ep in range(num_episodes)]
plt.plot(epsilon_values_over_episodes, label='Epsilon Value')
plt.xlabel('Episode')
plt.ylabel('Epsilon')
plt.title('Epsilon Decay Over Episodes')
plt.legend()
plt.grid(True)
plt.show()

# 3. Distribution of Final Rewards (Histogram)
# This can give you an idea of the consistency of the agent's performance
# especially towards the end of training.
plt.figure(figsize=(10, 6))
# Consider plotting rewards from the latter half of training for a more stable view
num_episodes_for_hist = len(rewards_all_episodes) // 2
plt.hist(rewards_all_episodes[-num_episodes_for_hist:], bins=30, edgecolor='black')
plt.xlabel('Total Reward in Episode')
plt.ylabel('Frequency')
plt.title(f'Distribution of Rewards (Last {num_episodes_for_hist} Episodes)')
plt.grid(axis='y', alpha=0.75)
plt.show()

print(f"Number of episodes plotted: {len(rewards_all_episodes)}")
if len(moving_avg_rewards) > 0:
    print(f"Final moving average reward (last {window_size} episodes of the moving average): {moving_avg_rewards[-1]:.2f}")
else:
    print("Not enough data for final moving average reward.")

# You can also print some summary statistics
print(f"\nSummary Statistics for All Episodes:")
print(f"Average reward: {np.mean(rewards_all_episodes):.2f}")
print(f"Standard deviation of reward: {np.std(rewards_all_episodes):.2f}")
print(f"Max reward: {np.max(rewards_all_episodes):.2f}")
print(f"Min reward: {np.min(rewards_all_episodes):.2f}")

# Statistics for the latter part of training (e.g., last 10% of episodes)
last_10_percent_idx = int(len(rewards_all_episodes) * 0.9)
if last_10_percent_idx < len(rewards_all_episodes): # Ensure there are enough episodes
    rewards_last_10_percent = rewards_all_episodes[last_10_percent_idx:]
    print(f"\nSummary Statistics for Last 10% of Episodes ({len(rewards_last_10_percent)} episodes):")
    print(f"Average reward: {np.mean(rewards_last_10_percent):.2f}")
    print(f"Standard deviation of reward: {np.std(rewards_last_10_percent):.2f}")
    print(f"Max reward: {np.max(rewards_last_10_percent):.2f}")
    print(f"Min reward: {np.min(rewards_last_10_percent):.2f}")
# Out:
# Number of episodes plotted: 25000
# Final moving average reward (last 100 episodes of the moving average): 20.71
#
# Summary Statistics for All Episodes:
# Average reward: -76.62
# Standard deviation of reward: 190.70
# Max reward: 47.50
# Min reward: -950.00
#
# Summary Statistics for Last 10% of Episodes (2500 episodes):
# Average reward: 19.99
# Standard deviation of reward: 21.50
# Max reward: 47.50
# Min reward: -282.50

# %%
final_avg_reward = np.mean(rewards_all_episodes[-1000:])
print(f"\nTraining Summary:")
print(f"Final epsilon: {epsilon:.3f}")
print(f"Average reward (last 1000 episodes): {final_avg_reward:.2f}")
print(f"Total episodes: {len(rewards_all_episodes)}")

# Display some Q-table statistics
print(f"\nQ-table Statistics:")
print(f"Non-zero Q-values: {np.count_nonzero(q_table)}/{q_table.size}")
print(f"Max Q-value: {np.max(q_table):.2f}")
print(f"Min Q-value: {np.min(q_table):.2f}")
print(f"Mean Q-value: {np.mean(q_table):.2f}")
# Out:
# Training Summary:
# Final epsilon: 0.128
# Average reward (last 1000 episodes): 20.66
# Total episodes: 25000
#
# Q-table Statistics:
# Non-zero Q-values: 2400/3000
# Max Q-value: 49.51
# Min Q-value: -6.25
# Mean Q-value: 19.55

# %%
# --- EVALUATION OF THE TRAINED AGENT ---

num_evaluation_episodes = 100
total_rewards_eval = 0
total_steps_eval = 0
successful_deliveries = 0

print("\n--- Starting Evaluation ---")

for episode in range(num_evaluation_episodes):
    state = env.reset()
    done = False
    episode_reward = 0
    episode_steps = 0

    while not done:
        # Choose action based purely on learned Q-values (exploitation)
        action = np.argmax(q_table[state, :])

        next_state, reward, done, info = env.step(action)

        state = next_state
        episode_reward += reward
        episode_steps += 1

        if done:
            if reward == 20: # Standard reward for successful drop-off in Taxi-v3
                successful_deliveries += 1
            break # Exit while loop for this episode

    total_rewards_eval += episode_reward
    total_steps_eval += episode_steps

    if (episode + 1) % 10 == 0:
        print(f"Evaluation Episode: {episode + 1}/{num_evaluation_episodes} | Reward: {episode_reward} | Steps: {episode_steps}")

# Calculate average statistics
avg_reward_eval = total_rewards_eval / num_evaluation_episodes
avg_steps_eval = total_steps_eval / num_evaluation_episodes
success_rate_eval = (successful_deliveries / num_evaluation_episodes) * 100

print("\n--- Evaluation Finished ---")
print(f"Total Episodes Evaluated: {num_evaluation_episodes}")
print(f"Average Reward per Episode: {avg_reward_eval:.2f}")
print(f"Average Steps per Episode: {avg_steps_eval:.2f}")
print(f"Success Rate (successful deliveries): {success_rate_eval:.2f}%")

# Compare with training performance (last 10% of training)
if 'rewards_last_10_percent' in locals() and len(rewards_last_10_percent) > 0:
    print(f"\nFor comparison (last 10% of training):")
    print(f"  Average reward: {np.mean(rewards_last_10_percent):.2f}")
else:
    print("\n(Training statistics for comparison not available in this session(run training cell again))")
# Out:
# --- Starting Evaluation ---
# Evaluation Episode: 10/100 | Reward: 22.0 | Steps: 17
# Evaluation Episode: 20/100 | Reward: 31.5 | Steps: 18
# Evaluation Episode: 30/100 | Reward: 43.5 | Steps: 14
# Evaluation Episode: 40/100 | Reward: 41.5 | Steps: 18
# Evaluation Episode: 50/100 | Reward: 33.0 | Steps: 35
# Evaluation Episode: 60/100 | Reward: 18.5 | Steps: 24
# Evaluation Episode: 70/100 | Reward: 41.5 | Steps: 18
# Evaluation Episode: 80/100 | Reward: 43.5 | Steps: 14
# Evaluation Episode: 90/100 | Reward: 29.5 | Steps: 22
# Evaluation Episode: 100/100 | Reward: 40.5 | Steps: 20
#
# --- Evaluation Finished ---
# Total Episodes Evaluated: 100
# Average Reward per Episode: 32.41
# Average Steps per Episode: 17.19
# Success Rate (successful deliveries): 0.00%
#
# For comparison (last 10% of training):
#   Average reward: 19.99

# %%
import time
from IPython.display import clear_output
import matplotlib.pyplot as plt

#trying to visualize with trained parameters

print("\n--- Visualizing One Episode ---")
state = env.reset()
done = False
max_steps_visualization = 50 # Set a max steps to prevent infinite loop if something is wrong
total_episode_reward_viz = 0


# env.render(mode='human') would open a window, if running in local system

for step_viz in range(max_steps_visualization):
    clear_output(wait=True) # to cllear the previous frame

    try:
        rendered_frame = env.render(mode='rgb_array')
        if rendered_frame is not None:
            plt.imshow(rendered_frame)
            plt.axis('off') # Turn off axis numbers and ticks
            plt.show()
        else:
            #fallback if it doesnot render This just prints text representation
            print(f"Step: {step_viz + 1}")
            env.render(mode='ansi') # Renders text-based to console output

    except Exception as e:
        print(f"Rendering error: {e}. Falling back to ANSI render.")
        env.render(mode='ansi')


    print(f"Current State: {state}, Total Reward: {total_episode_reward_viz}")

    # whichever action has max Q value we choose it
    action = np.argmax(q_table[state, :])

    next_state, reward, done, info = env.step(action)

    state = next_state
    total_episode_reward_viz += reward

    time.sleep(0.5) # Pausing here for 1/2 second to see frame

    if done:
        clear_output(wait=True)
        try:
            rendered_frame = env.render(mode='rgb_array')
            if rendered_frame is not None:
                plt.imshow(rendered_frame)
                plt.axis('off')
                plt.show()
            else:
                env.render(mode='ansi')
        except Exception as e:
            print(f"Rendering error on final step: {e}. Falling back to ANSI render.")
            env.render(mode='ansi')

        print(f"Episode Finished after {step_viz + 1} steps!")
        print(f"Final Reward for this episode: {total_episode_reward_viz}")
        if reward == 20:
            print("Passenger delivered successfully!")
        else:
            print("Episode ended for other reasons (e.g., max steps in a real scenario, or unexpected outcome).")
        break

if not done:
    print("Visualization stopped due to max_steps_visualization limit.")

# env.close() # Important if you used mode='human' or if render creates resources.
# For 'rgb_array' and 'ansi' it's often not strictly necessary but good practice.
# Out:
# Episode Finished after 16 steps!
# Final Reward for this episode: 42.5
# Episode ended for other reasons (e.g., max steps in a real scenario, or unexpected outcome).
